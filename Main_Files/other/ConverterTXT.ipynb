# %%
import pandas as pd
import re
import nltk as nk

# %%
# Recebe uma lista de token e retorna uma lista de token sem stopwords
def remove_stopwords(tokens):
    # Pega a lista de stopwords da biblioteca nltk
    stopwords = set(nk.corpus.stopwords.words('english'))
    frase_tratada = []
    # Qualquer palavra que não esteja na lista de stopwords é adicioinada em frase_tratada
    for palavra in tokens:
        if palavra not in stopwords:
            frase_tratada.append(palavra)
    return frase_tratada


# Recebe uma lista de tokens e retorna uma lista de tokens sem os caracteres especificados
def remove_caracter(tokens):
    token_tratado = []
    for word in tokens:
        word = re.sub('[.:;,+-=_!@#$?*()<>~^/|\'"]','', word)
        token_tratado.append(word)
    for w in token_tratado:
        if w == '':
            token_tratado.remove(w)
    return token_tratado


#Função para remover os emojis do texto
#by: https://stackoverflow.com/a/49146722/330558 & https://www.reddit.com/r/learnpython/comments/8br5sz/removing_emojis_from_words_python3/dx91wrm/
def remove_emoji(string):
    emoji_pattern = re.compile("["
                           "\U0001F600-\U0001F64F"  # emoticons
                           "\U0001F300-\U0001F5FF"  # symbols & pictographs
                           "\U0001F680-\U0001F6FF"  # transport & map symbols
                           "\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "\U00002702-\U000027B0"
                           "\U000024C2-\U0001F251"
                           "\U00010000-\U0010ffff"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', string)

# %%
# abre o arquivo correspondente
file = open("todos_commentarios.txt", "r", encoding="UTF-8")
#cria um pandas.DataFrame para armazena os resultados
df = pd.DataFrame(columns=["Avaliação", "Comentário"])
linha = file.readline()

# %%
while linha != "":
    linhaSep = linha.split(",",maxsplit=1)
    # separa toda a string da avaliação em uma lista, em que cada index é uma avaliação
    Avalliation = linhaSep[0]
    Comment = linhaSep[1]
    Tokenizer = nk.TweetTokenizer(reduce_len=3)
    Comment = remove_emoji(Comment)
    Comment = Tokenizer.tokenize(Comment)
    Comment = remove_stopwords(Comment)
    Comment = remove_caracter(Comment)
    # escreve em cada coluna do arquivo a sua avaliação e seu respectivo comentário.
    df = df.append({"Avaliação":Avalliation,"Comentário":Comment}, ignore_index=True)

    linha = file.readline()
df
# Out:
#       Avaliação                                         Comentário
# 0             5  [Im, report, I, think, bug, Its, great, app, b...
# 1             1  [Youtube, getting, bit, comfortable, putting, ...
# 2             2  [YouTube, please, fix, touching, progress, bar...
# 3             1  [This, app, horrible, The, video, pause, audio...
# 4             1  [Does, latest, update, bug, Everytime, I, try,...
# 5             3  [Initially, suitable, app, passing, time, cell...
# 6             1  [I, wish, I, update, app, Now, progress, bar, ...
# 7             1  [We, longer, tap, progress, bar, It, removed, ...
# 8             3  [Why, I, longer, tap, timeline, skip, point, N...
# 9             1  [Getting, worse, time, goes, Surely, getting, ...
# 10            1  [Awful, I, used, use, YT, time, But, recent, u...
# 11            3  [I, use, app, app, I, hate, ads, gotten, worse...
# 12            2  [Hello, youtube, Dont, update, version, apps, ...
# 13            3  [My, issue, last, update, I, longer, quick, la...
# 14            1  [The, ads, become, truly, ridiculous, They, in...
# 15            5  [great, learning, searching, creative, I, usus...
# 16            4  [I, love, YouTube, Premium, My, complaint, dow...
# 17            1  [Every, minutes, app, asks, Im, still, watchin...
# 18            3  [The, fact, exists, nice, fact, \, algorithm, ...
# 19            2  [Regardless, anyones, peeves, service, This, r...
# 20            3  [Every, time, I, try, use, YouTube, app, downl...
# 21            1  [Its, also, showing, explicit, ads, subscribin...
# 22            1  [I, hate, new, version, allowing, us, tap, ski...
# 23            1  [Heck, This, update, plain, stupid, The, play,...
# 24            2  [Too, many, ads, tablet, version, It, picture,...
# 25            1  [Freezing, long, spells, buffering, frequently...
# 26            1  [Suddenly, videos, pause, without, pausing, au...
# 27            1  [Useless, update, I, want, clearly, see, video...
# 28            1  [Recent, update, screwed, options, forward, ce...
# 29            1  [This, app, used, envy, world, The, must, best...
# ...         ...                                                ...
# 13989         5  [I, wouldve, rated, ten, stars, permitted, app...
# 13990         5  [More, information, useful, app, negative, vie...
# 13991         5  [Interesting, application, design, shortkeys, ...
# 13992         5  [More, information, useful, app, negative, rev...
# 13993         4  [Good, app, enables, young, old, learn, together]
# 13994         5  [Exactly, I, wanted, minimalist, trackpad, lik...
# 13995         5  [Exactly, I, wanted, minimal, wireless, way, c...
# 13996         5  [\, please, add, game, controller, \, best, ap...
# 13997         5  [Great, app, It, works, fine, Have, tried, hop...
# 13998         3  [nice, app, needed, phone, pc, I, need, work, ...
# 13999         1        [Not, android, tablets, Only, windows, mac]
# 14000         1                        [Cant, use, takes, forever]
# 14001         5        [Nice, app, would, like, know, I, get, app]
# 14002         1                                [Too, much, hassle]
# 14003         5                                            [Works]
# 14004         5                             [This, AWESOME, stars]
# 14005         5  [Finally, remote, mouse, keyboard, need, insta...
# 14006         5                                             [Cant]
# 14007         5                                          [amazing]
# 14008         5                           [Fantastic, application]
# 14009         5                                       [grest, app]
# 14010         4                                     [Very, useful]
# 14011         5  [Works, fine, thanks, Its, overpriced, paid, v...
# 14012         4  [Clean, simple, Linuxuniverse, remote, touchpa...
# 14013         5  [Exactly, I, need, A, WiFi, mouse, uses, vnc, ...
# 14014         5  [This, Finishing, Touch, able, control, extrem...
# 14015         5              [Good, app, support, VNC, encryption]
# 14016         5                             [Ittt, issues, fineee]
# 14017         4                                             [Like]
# 14018         1                                            [Sucks]
#
# [14019 rows x 2 columns]

# %%
df.to_csv("todos_commentarios.csv", index=False)
